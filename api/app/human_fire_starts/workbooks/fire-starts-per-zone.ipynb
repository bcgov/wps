# %%
import geopandas
gdf = geopandas.read_file('../data/PROT_HISTORICAL_INCIDENTS_SP.geojson')
gdf
# Out:
#        FIRE_NUMBER  FIRE_YEAR   IGNITION_DATE FIRE_CAUSE    FIRE_LABEL  \
# 0           K50756       2013  20130818091300     Person  2013-K50756
# 1           G90349       2004  20040717150300  Lightning  2004-G90349
# 2           G13106       2018  20181010155200    Unknown  2018-G13106
# 3           K61162       2002  20020923124900    Unknown  2002-K61162
# 4           N70289       2002  20020723154000  Lightning  2002-N70289
# ...            ...        ...             ...        ...           ...
# 187142      K60287       1998        19980729  Lightning   1998-K60287
# 187143      K60288       1998        19980728  Lightning   1998-K60288
# 187144      K60302       1998        19980728  Lightning   1998-K60302
# 187145      K60341       1998        19980731  Lightning   1998-K60341
# 187146      K60350       1998        19980731  Lightning   1998-K60350
#
#         FIRE_CENTRE  ZONE  FIRE_ID      FIRE_TYPE   GEOGRAPHIC_DESCRIPTION  \
# ...

# %%
import pandas as pd
# Filter out non-dates, map dates to datetimes, normalize all dates to midnight, convert all dates to unix timestamps
gdf['IGNITION_DATE'] = gdf['IGNITION_DATE'].dropna().map(pd.to_datetime).dt.normalize()
# Group by fire centre, zone and ignition date and get counts
out = gdf[['FIRE_CENTRE', 'ZONE', 'IGNITION_DATE']].groupby(['FIRE_CENTRE', 'ZONE', 'IGNITION_DATE']).size()
# Put groupby dataframe into a new frame without multi index so we get flat rows
out = out.to_frame(name = 'COUNT').reset_index()
out
# Out:
#      FIRE_CENTRE  ZONE IGNITION_DATE  COUNT
# 0            2.0   0.0    1969-12-31   7321
# 1            2.0   1.0    1970-01-01   6111
# 2            2.0   2.0    1969-12-31      1
# 3            2.0   2.0    1970-01-01    574
# 4            2.0   3.0    1970-01-01   3180
# ..           ...   ...           ...    ...
# 142          7.0  20.0    1970-01-01    348
# 143          7.0  21.0    1970-01-01    109
# 144          7.0  23.0    1970-01-01    226
# 145          7.0  24.0    1970-01-01    217
# 146          7.0  60.0    1970-01-01      1
#
# [147 rows x 4 columns]
